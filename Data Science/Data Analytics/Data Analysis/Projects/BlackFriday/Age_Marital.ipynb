# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('BlackFriday.csv')

del df['Product_Category_2']
del df['Product_Category_3']

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 164194  1001357  P00359342      M  46-50           0             C
# 482316  1002208  P00250242      M  26-35           0             C
# 482317  1002208  P00006842      M  26-35           0             C
# 482318  1002208  P00057942      M  26-35           0             C
# 482319  1002208  P00165842      M  26-35           0             C
# ...         ...        ...    ...    ...         ...           ...
# 427949  1005886  P00115942      M  26-35          20             A
# 427950  1005886  P00351342      M  26-35          20             A
# 427951  1005887  P00057542      F  36-45          20             C
# 427725  1005848  P00041242      M  51-55          20             A
# 344372  1005008  P00118442      M  26-35          20             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 164194                          1               1                  11
# ...

# %%
df_sorted = df.sort_values('Age')
ax = df_sorted.groupby('Age').size().plot(kind='bar', figsize=(12, 6), title='Purchase Distribution by Age')
plt.xticks(rotation=0)
plt.show()

# %%
lst = []
for i in df['Age'].unique():
    lst.append([i , df[df['Age']==i]['Product_ID'].nunique()])


data = pd.DataFrame(lst ,  columns = ['Age', 'No of Products'])

# %%
data
# Out:
#      Age  No of Products
# 0  46-50            3099
# 1  26-35            3419
# 2  18-25            3213
# 3  51-55            2877
# 4  36-45            3318
# 5    55+            2573
# 6   0-17            2300

# %%
ax = data.plot.bar(x = 'Age', figsize = (6,6))
plt.xticks(rotation=0)
plt.show()

# %%
df.groupby('Marital_Status').size()
# Out:
# Marital_Status
# 0    317817
# 1    219760
# dtype: int64

# %%
ax = df.groupby('Age')['Purchase'].sum().plot(kind = 'bar', figsize = (8, 6), title = 'Amount Spend by Age')
plt.xticks(rotation=0)
plt.show()

# %%
ax = df.groupby('Age')['Purchase'].mean().plot(kind = 'pie', figsize = (6, 6), title = 'Amount Spend by Age' , autopct = "%0.2f")
plt.xticks(rotation=0)
plt.show()

# %%
df.groupby('Marital_Status').size().plot(kind = 'pie',figsize=(6,6) , autopct = '%0.2f' , title='Married Percentage')
# Out:
# <Axes: title={'center': 'Married Percentage'}>

# %%
df.groupby('Gender').size().plot(kind = 'pie', autopct = '%0.2f' , figsize=(6,6) , title='Gender Percentage')
# Out:
# <Axes: title={'center': 'Gender Percentage'}>
